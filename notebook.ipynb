# %%
import pandas as pd
import numpy as np

df = pd.read_excel('Input - Anagrams.xlsx')

df['word1sorted'] = df['Word 1'].apply(lambda x: sorted(x.lower()))
df['word2sorted'] = df['Word 2'].apply(lambda x: sorted(x.lower()))
df['Anagram?'] = np.where(df["word1sorted"] == df["word2sorted"], 'Yes', 'No')

# %%
df
# Out:
#         Word 1     Word 2                     word1sorted  \
# 0      Tableau      Table           [a, a, b, e, l, t, u]
# 1         Prep       Repp                    [e, p, p, r]
# 2      Builder    Rebuild           [b, d, e, i, l, r, u]
# 3      Preppin     Nipper           [e, i, n, p, p, p, r]
# 4         Data       Date                    [a, a, d, t]
# 5     Cleaning   Enlacing        [a, c, e, g, i, l, n, n]
# 6       Filter     Trifle              [e, f, i, l, r, t]
# 7   Superstore  Resprouts  [e, e, o, p, r, r, s, s, t, u]
# 8      Allchin     Clinal           [a, c, h, i, l, l, n]
# 9       Martin      Train              [a, i, m, n, r, t]
# 10     Allenby     Lanely           [a, b, e, l, l, n, y]
# 11      Prowse     Powers              [e, o, p, r, s, w]
#
#                     word2sorted Anagram?
# 0               [a, b, e, l, t]       No
# 1                  [e, p, p, r]      Yes
# 2         [b, d, e, i, l, r, u]      Yes
# 3            [e, i, n, p, p, r]       No
# 4                  [a, d, e, t]       No
# 5      [a, c, e, g, i, l, n, n]      Yes
# 6            [e, f, i, l, r, t]      Yes
# 7   [e, o, p, r, r, s, s, t, u]       No
# 8            [a, c, i, l, l, n]       No
# 9               [a, i, n, r, t]       No
# 10           [a, e, l, l, n, y]       No
# 11           [e, o, p, r, s, w]      Yes
